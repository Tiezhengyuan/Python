# %% [markdown]
# # logging

# %% [markdown]
# ## simple tourial

# %%
#use print statements
def division(x,y):
    if y==0:
        print(f"denomenator can't be zero.")
        return None
    return x/y

division(3, 4)
division(3,0)
# Out:
# denomenator can't be zero.

# %%
# use logging
import logging

def division(x,y):
    if y==0:
        logging.error(f"denomenator can't be zero.")
        return None
    logging.info(f"export division")
    return x/y

division(3, 4)
division(3,0)
# Out:
# ERROR:root:denomenator can't be zero.

# %%
#Note: IPython session starts up logging. basicConfig doesn't work
import logging
logging.basicConfig(filename='python_debug.log', filemode='a', level=logging.DEBUG, 
    format='%(asctime)s:%(level)s:%(message)s', datefmt='%H:%M:%S')

def division(x,y):
    if y==0:
        logging.error(f"denomenator can't be zero.")
        return None
    if x==0:
        logging.warning(f"numerator is zero")
    logging.info(f"export division")
    return x/y

division(3, 4)
division(3,0)
division(0,4)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'level'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'level'
# Call stack:
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2877, in run_cell
#     result = self._run_cell(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-39-629e993d502a>", line 15, in <module>
#     division(3, 4)
#   File "<ipython-input-39-629e993d502a>", line 12, in division
#     logging.info(f"export division")
# Message: 'export division'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'level'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'level'
# Call stack:
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2877, in run_cell
#     result = self._run_cell(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-39-629e993d502a>", line 16, in <module>
#     division(3,0)
#   File "<ipython-input-39-629e993d502a>", line 8, in division
#     logging.error(f"denomenator can't be zero.")
# Message: "denomenator can't be zero."
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'level'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'level'
# Call stack:
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2877, in run_cell
#     result = self._run_cell(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-39-629e993d502a>", line 17, in <module>
#     division(0,4)
#   File "<ipython-input-39-629e993d502a>", line 11, in division
#     logging.warning(f"numerator is zero")
# Message: 'numerator is zero'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'level'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'level'
# Call stack:
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2877, in run_cell
#     result = self._run_cell(
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\tiezh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-39-629e993d502a>", line 17, in <module>
#     division(0,4)
#   File "<ipython-input-39-629e993d502a>", line 12, in division
#     logging.info(f"export division")
# Message: 'export division'
# Arguments: ()
# 0.0

# %%
import logging
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='python_debug.log', mode='a')
formatter = logging.Formatter('%(asctime)s:%(level)s:%(message)s', datefmt='%H:%M:%S')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.DEBUG)
    

def division(x,y):
    if y==0:
        logging.error(f"denomenator can't be zero.")
        return None
    if x==0:
        logging.warning(f"numerator is zero")
    logging.info(f"export division")
    return x/y

division(3, 4)
division(3,0)
division(0,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-c562797bf368> in <module>
#       1 from os import path
# ----> 2 log_file_path = path.join(path.dirname(path.abspath(__file__)), 'log.config')
#       3 logging.config.fileConfig(log_file_path)
#       4
#       5 import logging
#
# NameError: name '__file__' is not defined
